# %%
import torch
import torch.nn as nn
from torch.distributions import Categorical
from nes_py.wrappers import JoypadSpace
import gym_super_mario_bros
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
import gym
from gym.vector import SyncVectorEnv
import cv2
import numpy as np
import matplotlib.pyplot as plt
from collections import deque
import PIL
from PIL import Image
from IPython.core.display import clear_output

print(Image.__file__)
# Out:
# Warning: Gym version v0.24.1 has a number of critical issues with `gym.make` such that environment observation and action spaces are incorrectly evaluated, raising incorrect errors and warning . It is recommend to downgrading to v0.23.1 or upgrading to v0.25.1
# /home/lharms/.local/lib/python3.10/site-packages/PIL/Image.py
# /tmp/ipykernel_30576/1252695180.py:15: DeprecationWarning: Importing clear_output from IPython.core.display is deprecated since IPython 7.14, please import from IPython.display
#   from IPython.core.display import clear_output

# %% [markdown]
# ## Actor Critic

# %%
class ActorCritic(nn.Module):
    def __init__(self, action_dim):
        super(ActorCritic, self).__init__()

        self.cnn = nn.Sequential(
            nn.Conv2d(4, 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU(),
            nn.Flatten()
        )

        self.actor = nn.Sequential(
            nn.Linear(3136, 512),
            nn.ReLU(),
            nn.Linear(512, action_dim),
            nn.Softmax(dim=-1)
        )

        self.critic = nn.Sequential(
            nn.Linear(3136, 512),
            nn.ReLU(),
            nn.Linear(512, 1)
        )

    def extract_features(self, state):
        return self.cnn(state)

    def act(self, state):  # state: (B, C, H, W)
        with torch.no_grad():
            features = self.extract_features(state)              # (B, feature_dim)
            probs = self.actor(features)                         # (B, action_dim)
            dist = Categorical(probs)
            actions = dist.sample()                              # (B,)
            log_probs = dist.log_prob(actions)                   # (B,)
            entropy = dist.entropy()
            return actions, log_probs, entropy

    def evaluate(self, states, actions):
        features = self.extract_features(states)
        probs = self.actor(features)
        dist = Categorical(probs)
        log_probs = dist.log_prob(actions)
        entropy = dist.entropy()
        values = self.critic(features).squeeze(-1)
        return log_probs, entropy, values

# %% [markdown]
# #### A2C

# %%
class A2C:
    def __init__(self, action_dim, lr_actor, lr_critic, gamma):
        self.policy = ActorCritic(action_dim).to('cpu')
        self.optimizer = torch.optim.Adam([
            {'params': self.policy.actor.parameters(), 'lr': lr_actor},
            {'params': self.policy.critic.parameters(), 'lr': lr_critic}
        ])
        self.gamma = gamma
        self.lam = 0.95 # für GAE

    def select_action(self, state):
        state_tensor = state.to("cpu") if isinstance(state, torch.Tensor) else torch.FloatTensor(state).to("cpu")
        return self.policy.act(state_tensor)

    def compute_gae(self, rewards, values, dones, next_value):
        T, N = rewards.size()  # (n_steps, num_envs)
        advantages = torch.zeros_like(rewards)
        gae = torch.zeros(N)

        for t in reversed(range(T)):
            mask = 1.0 - dones[t]
            delta = rewards[t] + self.gamma * next_value * mask - values[t]
            gae = delta + self.gamma * self.lam * mask * gae
            advantages[t] = gae
            next_value = values[t]

        returns = advantages + values
        return advantages, returns


    def update_parallel(self, states, actions, log_probs, rewards, dones, next_state_batch, entropies):
        # next_value: Critic-Wert des letzten Zustands (Bootstrap)
        with torch.no_grad():
            final_tensor = torch.FloatTensor(next_state_batch)
            next_value = self.policy.critic(self.policy.extract_features(final_tensor)).squeeze(-1)  # (num_envs,)

        # Sammle Werte (Critic) für alle vorherigen Zustände
        all_values = []
        for s in states:
            with torch.no_grad():
                v = self.policy.critic(self.policy.extract_features(s)).squeeze(-1)  # (num_envs,)
            all_values.append(v)

        # rewards, dones sind Listen aus (num_envs,) Tensoren
        values_tensor = torch.stack(all_values)  # (n_steps, num_envs)
        rewards_tensor = torch.stack(rewards_per_step)  # (n_steps, num_envs)
        dones_tensor = torch.stack(dones_per_step)  # (n_steps, num_envs)

        advantages, returns = self.compute_gae(
            rewards_tensor, values_tensor, dones_tensor, next_value
        )


        log_probs = torch.stack(log_probs)       # (n_steps, num_envs)
        actions = torch.stack(actions)           # (n_steps, num_envs)
        entropies = torch.stack(entropies)       # (n_steps, num_envs)

        states = torch.cat(states, dim=0)        # (n_steps * num_envs, ...)
        returns = returns.view(-1)               # (n_steps * num_envs,)
        actions = actions.view(-1)
        log_probs = log_probs.view(-1)
        entropy = entropies.view(-1)
        advantages = advantages.view(-1)

        # Vorteil normalisieren
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        # Aktueller Wert des Kritikers
        values = self.policy.critic(self.policy.extract_features(states)).squeeze(-1)

        actor_loss = - (log_probs * advantages).mean()
        critic_loss = torch.nn.functional.mse_loss(values, returns)
        loss = actor_loss + 0.5 * critic_loss - 0.1 * entropy.mean() # statt 0.03 #statt 0.01

        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.policy.parameters(), 0.5)
        self.optimizer.step()

# %% [markdown]
# #### environment

# %%
def make_env():
    def _thunk():
        env = gym_super_mario_bros.make('SuperMarioBros-v1')
        env = JoypadSpace(env, SIMPLE_MOVEMENT)
        env = SkipFrame(env, skip=frameskip)
        env = DeadlockEnv(env, threshold=(60 * 2) // frameskip)
        return env
    return _thunk

#This environment wrapper is used to stop a run if mario is stuck on a pipe
class DeadlockEnv(gym.Wrapper):
    def __init__(self, env, threshold=80):
        super().__init__(env)
        self.last_x_pos = 0
        self.count = 0
        self.threshold = threshold
        self.lifes = 3
        self.stage = 1
        self.world = 1
        self.last_coins = 0

        self.start_xpos = None

    def reset(self, **kwargs):
        self.last_x_pos = 0
        self.count = 0
        self.start_xpos = None
        self.lifes = 3
        self.stage = 1
        self.world = 1
        self.last_coins = 0

        return self.env.reset(**kwargs)

    def step(self, action):
        state, reward, done, info = self.env.step(action)
        x_pos = info['x_pos']

        if self.start_xpos is None:
            self.start_xpos = x_pos

       # if x_pos > self.last_x_pos:
        #   reward += 2

        if x_pos <= self.last_x_pos:
            self.count += 1
        else:
            self.count = 0

        if info['life'] != self.lifes or info["stage"] != self.stage or info["world"] != self.world:
            self.last_x_pos = x_pos
            self.count = 0
            self.lifes = info['life']
            self.stage = info["stage"]
            self.world = info["world"]

        # ==== hier Veränderung ====
        coins_delta = info['coins'] - self.last_coins
        reward += min(coins_delta * 0.1, 2.0)  # statt coins_delta * 0.2
        self.last_coins = info['coins']

        if info.get("flag_get", False):
            reward += 20  # Bonus für Levelabschluss #statt 100
            done = True

        delta = x_pos - self.last_x_pos
        if delta > 0:
            reward += min(delta * 0.05, 2.0) # statt delta * 0.05 # statt 0.1
        else:
            reward -= 0.01 # stehenbleiben

        self.last_x_pos = x_pos
        # ===========================

        if self.count >= self.threshold:
            reward = -5 #statt 15
            done = True

        distance = x_pos - self.start_xpos
        info['distance'] = distance
        return state, reward, done, info


#skipframe wrapper
class SkipFrame(gym.Wrapper):
    def __init__(self, env, skip):
        super().__init__(env)
        self._skip = skip

    def step(self, action):
        reward_out = 0
        for i in range(self._skip):
            obs, reward, done, info = self.env.step(action)
            reward_out += reward
            if done:
                break
        reward_out /= max(1,i+1)

        return obs, reward_out, done, info

#downsample wrapper to reduce dimensionality
def Downsample(ratio,state):
  (oldh, oldw, oldc) = state.shape
  newshape = (oldh//ratio, oldw//ratio, oldc)
  frame = cv2.resize(state, (newshape[0], newshape[1]), interpolation=cv2.INTER_AREA)
  return frame

#small function to change rgb images to grayscale
def GrayScale(state):
  return cv2.cvtColor(state, cv2.COLOR_RGB2GRAY)

# %% [markdown]
# #### Training

# %%
#renders given frames with mediapy and shows a video
def renderEnv(frames):
  import mediapy as media
  media.show_video(frames,fps=60//4)

#plot for visualizing results
def plotRewardandTime(avg_norm_reward,avg_length):
  import matplotlib.pyplot as plt
  x = np.arange(len(avg_norm_reward))

  fig, axs = plt.subplots(1, 2,figsize=(9,3))

  axs[0].plot(x, avg_norm_reward)
  axs[0].set_title("avg_norm_reward")

  axs[1].plot(x, avg_length)
  axs[1].set_title("avg_length")
  plt.show()

def get_base_env(env):
    while hasattr(env, 'env'):
        env = env.env
    return env

def record(env, agent, max_steps=500):
    frames = []
    obs = env.reset()  # Altes Gym API, obs ist keine Tuple

    # Frame-Stack vorbereiten
    frame_buffer = deque(maxlen=frame_stack)

    # Erstes Bild preprocessen und Stack füllen
    img = GrayScale(Downsample(down_sample_rate, obs))
    img = cv2.resize(img, (84, 84)) / 255.0
    for _ in range(frame_stack):
        frame_buffer.append(img)

    done = False
    steps = 0

    while not done and steps < max_steps:
        # Frame fürs Video sammeln: Env liefert RGB Bild
        base_env = get_base_env(env)
        print(base_env)
        frame = base_env.render(mode="rgb_array")
        if frame is None:
            print("Frame is None!")
        elif frame.max() == 0:
            print("Frame ist komplett schwarz.")
        #else:
            #print(f"Frame OK: {frame.shape}, dtype={frame.dtype}")

        frames.append(frame)

        # Agent sieht den gepufferten Frame-Stack (4, 84, 84)
        state = np.stack(frame_buffer, axis=0)
        state_tensor = torch.FloatTensor(state).unsqueeze(0)  # (1, 4, 84, 84)

        action, _, _ = agent.select_action(state_tensor)
        obs, reward, done, _ = env.step(action.item())

        # Neues Bild preprocessen und Stack aktualisieren
        img = GrayScale(Downsample(down_sample_rate, obs))
        img = cv2.resize(img, (84, 84)) / 255.0
        frame_buffer.append(img)

        #print(f"Step {steps}: action={action.item()}, reward={reward}, done={done}")
        steps += 1

    print(f"Gesammelte Frames: {len(frames)}")
    return frames


def save_video_cv2(frames, path, fps=15):
    if not frames:
        print("Keine Frames zum Speichern!")
        return

    height, width, _ = frames[0].shape
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(path, fourcc, fps, (width, height))

    for i, frame in enumerate(frames):
        bgr = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
        out.write(bgr)
        if (i + 1) % 100 == 0:
            print(f"{i+1}/{len(frames)} Frames geschrieben...")

    out.release()
    print(f"Video erfolgreich gespeichert: {path}")

# %%
# ==== Hyperparameter ====
frameskip = 4
down_sample_rate = 4
lr_actor = 1e-4 # statt 0.0003
lr_critic = 5e-4 # statt 0.001
gamma = 0.995 # statt 0.99
frame_stack = 4
num_envs = 8
n_steps = 256 # statt 1000
max_epochs = 500
window_size = 10
video_env_id = 0

episode_rewards = [0.0 for _ in range(num_envs)]
episode_lengths = [0 for _ in range(num_envs)]

# Für Statistik
rewards_log = []
lengths_log = []
avg_reward = []
avg_length = []
avg_distance = []

# ==== Environment Setup ====
def make_env():
    def _thunk():
        env = gym_super_mario_bros.make('SuperMarioBros-v1')
        env = JoypadSpace(env, SIMPLE_MOVEMENT)
        env = SkipFrame(env, skip=frameskip)
        env = DeadlockEnv(env, threshold=(60 * 2) // frameskip)
        return env
    return _thunk

envs = SyncVectorEnv([make_env() for _ in range(num_envs)])
render_env = make_env()()

action_dim = envs.single_action_space.n

# ==== Agent Setup ====
agent = A2C(action_dim=action_dim, lr_actor=lr_actor, lr_critic=lr_critic, gamma=gamma)

# ==== FrameStack Buffer pro Environment ====
frame_buffers = [deque(maxlen=frame_stack) for _ in range(num_envs)]
obs = envs.reset()

# Preprocessing initial state
def preprocess(obs):
    processed = []
    for i in range(num_envs):
        img = GrayScale(Downsample(down_sample_rate, obs[i]))
        img = cv2.resize(img, (84, 84)) / 255.0
        for _ in range(frame_stack):
            frame_buffers[i].append(img)
        processed.append(np.stack(frame_buffers[i], axis=0))
    return np.stack(processed)

state_batch = preprocess(obs)

# ==== Training Loop ====
for epoch in range(max_epochs):
    all_states, all_actions, all_log_probs = [], [], []
    rewards_per_step, dones_per_step, entropy_per_step = [], [], []
    frames = []
    highest_length, highest_reward, highest_distance = 0, 0, 0

    for _ in range(n_steps):
        state_tensor = torch.FloatTensor(state_batch)  # (num_envs, 4, 84, 84)
        actions, log_probs, entropies = agent.select_action(state_tensor)

        obs, rewards, dones, info = envs.step(actions.numpy())

        # Für Statistik
        for i in range(num_envs):
            episode_rewards[i] += rewards[i]
            episode_lengths[i] += 1

            if dones[i]:
                if episode_lengths[i] > highest_length:
                    highest_length = episode_lengths[i]
                elif episode_rewards[i] > highest_reward:
                    highest_reward = episode_rewards[i]
                print(f"Env {i} done! Reward: {episode_rewards[i]}, Length: {episode_lengths[i]}, Distance: {info['distance'][i]}")
                print(f"[DEBUG] x_pos: {info['x_pos'][0]} | coins: {info['coins'][0]} | distance: {info['distance'][0]}")
                rewards_log.append(episode_rewards[i])
                lengths_log.append(episode_lengths[i])
                episode_rewards[i] = 0.0
                episode_lengths[i] = 0
                if info['distance'][i] > highest_distance:
                    highest_distance = info['distance'][i]
                avg_distance.append(info['distance'][i])

        # nächster Zustand verarbeiten
        next_state_stack = []
        for i in range(num_envs):
            img = GrayScale(Downsample(down_sample_rate, obs[i]))
            img = cv2.resize(img, (84, 84)) / 255.0
            frame_buffers[i].append(img)
            stacked = np.stack(frame_buffers[i], axis=0)
            next_state_stack.append(stacked)
        state_batch = np.stack(next_state_stack)

        # Logging der Trainingsdaten
        all_states.append(state_tensor)
        all_actions.append(actions)
        all_log_probs.append(log_probs)
        rewards_per_step.append(torch.tensor(rewards, dtype=torch.float32))
        dones_per_step.append(torch.tensor(dones, dtype=torch.float32))
        entropy_per_step.append(entropies)


    # === Update ===
    agent.update_parallel(
        all_states, all_actions, all_log_probs,
        rewards_per_step, dones_per_step, state_batch,
        entropy_per_step
    )

    # === Statistik aktualisieren ===
    if len(rewards_log) >= window_size:
        # Gleitender Durchschnitt über letzte window_size Episoden
        avg_reward_epoch = np.mean(rewards_log[-window_size:])
        avg_length_epoch = np.mean(lengths_log[-window_size:])
    elif rewards_log:  # Falls weniger als window_size Episoden
        avg_reward_epoch = np.mean(rewards_log)
        avg_length_epoch = np.mean(lengths_log)
    else:
        # Fallback wenn noch keine Episoden beendet
        avg_reward_epoch = 0
        avg_length_epoch = 0

    avg_reward.append(avg_reward_epoch)
    avg_length.append(avg_length_epoch)

    print(f"\n=== EPOCH {epoch+1} SUMMARY ===")
    print("avg_reward:", avg_reward[-5:])
    print("avg_length:", avg_length[-5:])
    print("avg_distance:", avg_distance[-5:])
    print(f"Epoch {epoch+1} | Avg Reward: {avg_reward_epoch:.2f} | Avg Length: {avg_length_epoch:.1f}")

    if epoch % 50 == 0:
        torch.save(agent.policy.state_dict(), f"../../runs/A2C/03_testA2C/16_inc_entropy/a2c_epoch_{epoch}.pt")

        #frames = record(render_env, agent)
        #print(len(frames))
        #save_video_cv2(frames, f"../../runs/A2C/03_testA2C/10_reward_shaping_2/videos/mario_epoch{epoch}.mp4")


fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
#ax3 = ax1.twinx()

x = np.arange(len(avg_reward))
line1 = ax1.plot(x, avg_reward, 'b-', label='Avg Reward')
line2 = ax2.plot(x, avg_length, 'r-', label='Avg Length')
#line3 = ax3.plot(x, avg_distance, 'g-', label='Avg Distance')

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Avg Reward', color='b')
ax2.set_ylabel('Avg Length', color='r')
#ax3.set_ylabel('Avg Distance', color='g')
plt.title("Training Progress")

fig.tight_layout()
fig.legend(loc="upper left")
plt.show()


print("===== Results =====")
print(f"Avg Reward: {np.mean(avg_reward):.2f} | Avg Length: {np.mean(avg_length):.2f} | Avg Distance: {np.mean(avg_distance):.2f}")
print(f"Highest Reward: {highest_reward} | Highest Length: {highest_length} | Highest Distance: {highest_distance}")
# Out:
# /home/lharms/.local/lib/python3.10/site-packages/gym/envs/registration.py:564: UserWarning: WARN: The environment SuperMarioBros-v1 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# /home/lharms/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:97: UserWarning: WARN: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
#   logger.warn(
# Env 4 done! Reward: 182.97333333333327, Length: 157, Distance: 236
# [DEBUG] x_pos: 368 | coins: 0 | distance: 328
# Env 1 done! Reward: 228.9700000000006, Length: 193, Distance: 553
# [DEBUG] x_pos: 582 | coins: 0 | distance: 542
# Env 6 done! Reward: 185.58000000000067, Length: 208, Distance: 667
# [DEBUG] x_pos: 592 | coins: 0 | distance: 552
#
# === EPOCH 1 SUMMARY ===
# avg_reward: [199.17444444444482]
# avg_length: [186.0]
# avg_distance: [236, 553, 667]
# Epoch 1 | Avg Reward: 199.17 | Avg Length: 186.0
# Env 0 done! Reward: 317.4800000000009, Length: 260, Distance: 662
# [DEBUG] x_pos: 702 | coins: 0 | distance: 662
# Env 1 done! Reward: 201.39666666666656, Length: 174, Distance: 243
# [DEBUG] x_pos: 530 | coins: 0 | distance: 490
# Env 7 done! Reward: 182.76000000000204, Length: 372, Distance: 682
# [DEBUG] x_pos: 587 | coins: 0 | distance: 547
# Env 5 done! Reward: 174.65000000000322, Length: 477, Distance: 674
# [DEBUG] x_pos: 719 | coins: 0 | distance: 679
# Env 0 done! Reward: 187.30000000000058, Length: 220, Distance: 669
# [DEBUG] x_pos: 709 | coins: 0 | distance: 669
#
# === EPOCH 2 SUMMARY ===
# avg_reward: [199.17444444444482, 207.63875000000098]
# avg_length: [186.0, 257.625]
# avg_distance: [662, 243, 682, 674, 669]
# Epoch 2 | Avg Reward: 207.64 | Avg Length: 257.6
# Env 4 done! Reward: 432.9200000000015, Length: 424, Distance: 682
# [DEBUG] x_pos: 80 | coins: 1 | distance: 40
# Env 7 done! Reward: 314.8800000000007, Length: 234, Distance: 261
# [DEBUG] x_pos: 224 | coins: 1 | distance: 184
# Env 1 done! Reward: 371.50333333333447, Length: 303, Distance: 827
# [DEBUG] x_pos: 598 | coins: 1 | distance: 558
# Env 3 done! Reward: 467.3100000000042, Length: 679, Distance: 258
# [DEBUG] x_pos: 644 | coins: 1 | distance: 604
#
# === EPOCH 3 SUMMARY ===
# avg_reward: [199.17444444444482, 207.63875000000098, 283.57800000000145]
# avg_length: [186.0, 257.625, 335.1]
# avg_distance: [669, 682, 261, 827, 258]
# Epoch 3 | Avg Reward: 283.58 | Avg Length: 335.1
# Env 0 done! Reward: 346.200000000002, Length: 392, Distance: 787
# [DEBUG] x_pos: 827 | coins: 1 | distance: 787
# Env 4 done! Reward: 303.85000000000053, Length: 324, Distance: 260
# [DEBUG] x_pos: 282 | coins: 0 | distance: 242
# Env 6 done! Reward: 359.8200000000048, Length: 701, Distance: 682
# [DEBUG] x_pos: 307 | coins: 0 | distance: 267
# Env 5 done! Reward: 488.06000000000296, Length: 455, Distance: 682
# [DEBUG] x_pos: 338 | coins: 0 | distance: 298
#
# === EPOCH 4 SUMMARY ===
# avg_reward: [199.17444444444482, 207.63875000000098, 283.57800000000145, 344.6493333333355]
# avg_length: [186.0, 257.625, 335.1, 420.9]
# avg_distance: [258, 787, 260, 682, 682]
# Epoch 4 | Avg Reward: 344.65 | Avg Length: 420.9
# Env 3 done! Reward: 330.65000000000214, Length: 382, Distance: 677
# [DEBUG] x_pos: 594 | coins: 0 | distance: 554
# Env 7 done! Reward: 488.6600000000035, Length: 523, Distance: 651
# [DEBUG] x_pos: 600 | coins: 0 | distance: 560
# Env 4 done! Reward: 256.5500000000005, Length: 229, Distance: 682
# [DEBUG] x_pos: 613 | coins: 0 | distance: 573
# Env 2 done! Reward: 505.230000000008, Length: 1228, Distance: 249
# [DEBUG] x_pos: 77 | coins: 1 | distance: 37
# Env 5 done! Reward: 183.76000000000147, Length: 319, Distance: 676
# [DEBUG] x_pos: 266 | coins: 1 | distance: 226
# Env 1 done! Reward: 436.7400000000032, Length: 603, Distance: 682
# [DEBUG] x_pos: 411 | coins: 1 | distance: 371
#
# === EPOCH 5 SUMMARY ===
# avg_reward: [199.17444444444482, 207.63875000000098, 283.57800000000145, 344.6493333333355, 369.95200000000295]
# avg_length: [186.0, 257.625, 335.1, 420.9, 515.6]
# avg_distance: [651, 682, 249, 676, 682]
# Epoch 5 | Avg Reward: 369.95 | Avg Length: 515.6
# Env 0 done! Reward: 443.72000000000503, Length: 644, Distance: 681
# [DEBUG] x_pos: 721 | coins: 1 | distance: 681
# Env 7 done! Reward: 425.8700000000017, Length: 398, Distance: 649
# [DEBUG] x_pos: 72 | coins: 0 | distance: 32
#
# === EPOCH 6 SUMMARY ===
# avg_reward: [207.63875000000098, 283.57800000000145, 344.6493333333355, 369.95200000000295, 391.9060000000033]
# avg_length: [257.625, 335.1, 420.9, 515.6, 548.2]
# avg_distance: [249, 676, 682, 681, 649]
# Epoch 6 | Avg Reward: 391.91 | Avg Length: 548.2
# Env 3 done! Reward: 248.0400000000032, Length: 543, Distance: 683
# [DEBUG] x_pos: 722 | coins: 0 | distance: 682
# Env
# avg_length: [502.9, 508.3, 487.2, 542.5, 607.2]
# avg_distance: [857, 683, 681, 856, 553]
# Epoch 19 | Avg Reward: 381.49 | Avg Length: 607.2
#
# === EPOCH 20 SUMMARY ===
# avg_reward: [355.44866666666957, 354.6923333333361, 359.06966666666983, 381.49166666667054, 381.49166666667054]
# avg_length: [508.3, 487.2, 542.5, 607.2, 607.2]
# avg_distance: [857, 683, 681, 856, 553]
# Epoch 20 | Avg Reward: 381.49 | Avg Length: 607.2
# Env 4 done! Reward: 587.3800000000062, Length: 1599, Distance: 858
# [DEBUG] x_pos: 722 | coins: 2 | distance: 682
# Env 2 done! Reward: 214.10000000000505, Length: 776, Distance: 834
# [DEBUG] x_pos: 722 | coins: 2 | distance: 682
# Env 3 done! Reward: 158.49000000000711, Length: 964, Distance: 679
# [DEBUG] x_pos: 720 | coins: 2 | distance: 680
#
# === EPOCH 21 SUMMARY ===
# avg_reward: [354.6923333333361, 359.06966666666983, 381.49166666667054, 381.49166666667054, 384.4470000000048]
# avg_length: [487.2, 542.5, 607.2, 607.2, 785.1]
# avg_distance: [856, 553, 858, 834, 679]
# Epoch 21 | Avg Reward: 384.45 | Avg Length: 785.1
# Env 1 done! Reward: 239.9800000000053, Length: 744, Distance: 681
# [DEBUG] x_pos: 898 | coins: 2 | distance: 858
# Env 0 done! Reward: 410.52000000000453, Length: 653, Distance: 853
# [DEBUG] x_pos: 893 | coins: 2 | distance: 853
# Env 7 done! Reward: 426.90000000000475, Length: 751, Distance: 682
# [DEBUG] x_pos: 434 | coins: 0 | distance: 395
# Env 6 done! Reward: 589.7600000000043, Length: 1039, Distance: 681
# [DEBUG] x_pos: 497 | coins: 0 | distance: 458
# Env 4 done! Reward: 539.420000000003, Length: 496, Distance: 646
# [DEBUG] x_pos: 594 | coins: 0 | distance: 555
# Env 2 done! Reward: 229.78000000000267, Length: 477, Distance: 856
# [DEBUG] x_pos: 594 | coins: 0 | distance: 555
#
# === EPOCH 22 SUMMARY ===
# avg_reward: [359.06966666666983, 381.49166666667054, 381.49166666667054, 384.4470000000048, 380.58400000000455]
# avg_length: [542.5, 607.2, 607.2, 785.1, 793.9]
# avg_distance: [853, 682, 681, 646, 856]
# Epoch 22 | Avg Reward: 380.58 | Avg Length: 793.9
# Env 6 done! Reward: 317.60000000000036, Length: 208, Distance: 267
# [DEBUG] x_pos: 182 | coins: 0 | distance: 143
# Env 3 done! Reward: 180.26000000000252, Length: 450, Distance: 682
# [DEBUG] x_pos: 243 | coins: 0 | distance: 204
# Env 1 done! Reward: 484.810000000002, Length: 347, Distance: 275
# [DEBUG] x_pos: 434 | coins: 0 | distance: 395
# Env 2 done! Reward: 145.23000000000073, Length: 247, Distance: 533
# [DEBUG] x_pos: 594 | coins: 0 | distance: 555
#
# === EPOCH 23 SUMMARY ===
# avg_reward: [381.49166666667054, 381.49166666667054, 384.4470000000048, 380.58400000000455, 356.42600000000306]
# avg_length: [607.2, 607.2, 785.1, 793.9, 541.2]
# avg_distance: [856, 267, 682, 275, 533]
Distance: 682
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
# Env 2 done! Reward: 474.1700000000043, Length: 872, Distance: 260
# [DEBUG] x_pos: 721 | coins: 1 | distance: 681
#
# === EPOCH 40 SUMMARY ===
# avg_reward: [368.31766666667085, 353.62566666667027, 389.68633333333617, 367.1430000000025, 392.39400000000353]
# avg_length: [721.4, 639.3, 550.4, 486.9, 638.3]
# avg_distance: [213, 683, 209, 682, 260]
# Epoch 40 | Avg Reward: 392.39 | Avg Length: 638.3
# Env 5 done! Reward: 183.51000000000207, Length: 394, Distance: 682
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
# Env 3 done! Reward: 180.16000000000224, Length: 458, Distance: 683
# [DEBUG] x_pos: 721 | coins: 1 | distance: 681
# Env 1 done! Reward: 435.920000000002, Length: 351, Distance: 272
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
# Env 2 done! Reward: 377.72333333333506, Length: 359, Distance: 259
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
# Env 4 done! Reward: 728.3600000000026, Length: 583, Distance: 810
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
#
# === EPOCH 41 SUMMARY ===
# avg_reward: [353.62566666667027, 389.68633333333617, 367.1430000000025, 392.39400000000353, 382.2416666666695]
# avg_length: [639.3, 550.4, 486.9, 638.3, 532.6]
# avg_distance: [682, 683, 272, 259, 810]
# Epoch 41 | Avg Reward: 382.24 | Avg Length: 532.6
# Env 0 done! Reward: 144.20000000000937, Length: 1234, Distance: 667
# [DEBUG] x_pos: 707 | coins: 1 | distance: 667
# Env 6 done! Reward: 195.70000000000772, Length: 1140, Distance: 823
# [DEBUG] x_pos: 365 | coins: 1 | distance: 325
# Env 7 done! Reward: 663.2500000000056, Length: 1018, Distance: 682
# [DEBUG] x_pos: 615 | coins: 1 | distance: 575
#
# === EPOCH 42 SUMMARY ===
# avg_reward: [389.68633333333617, 367.1430000000025, 392.39400000000353, 382.2416666666695, 353.6833333333378]
# avg_length: [550.4, 486.9, 638.3, 532.6, 743.5]
# avg_distance: [259, 810, 667, 823, 682]
# Epoch 42 | Avg Reward: 353.68 | Avg Length: 743.5
# Env 1 done! Reward: 488.3100000000016, Length: 410, Distance: 858
# [DEBUG] x_pos: 115 | coins: 1 | distance: 75
# Env 3 done! Reward: 449.4500000000025, Length: 443, Distance: 764
# [DEBUG] x_pos: 359 | coins: 1 | distance: 319
# Env 4 done! Reward: 555.9600000000019, Length: 486, Distance: 553
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
#
# === EPOCH 43 SUMMARY ===
# avg_reward: [367.1430000000025, 392.39400000000353, 382.2416666666695, 353.6833333333378, 421.9033333333371]
# avg_length: [486.9, 638.3, 532.6, 743.5, 648.2]
# avg_distance: [823, 682, 858, 764, 553]
# Epoch 43 | Avg Reward: 421.90 | Avg Length: 648.2
# Env 3 done! Reward: 354.51000000000107, Length: 298, Distance: 770
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
# Env 7 done! Reward: 301.08000000000237, Length: 464, Distance: 858
# [DEBUG] x_pos: 702 | coins: 1 | distance: 662
# Env 5 done! Reward: 284.03000000000605, Length: 855, Distance: 858
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
# Env
# [DEBUG] x_pos: 722 | coins: 0 | distance: 682
# Env 0 done! Reward: 253.71000000000288, Length: 466, Distance: 680
# [DEBUG] x_pos: 720 | coins: 0 | distance: 680
# Env 7 done! Reward: 373.2966666666691, Length: 457, Distance: 258
# [DEBUG] x_pos: 418 | coins: 1 | distance: 378
# Env 5 done! Reward: 472.54333333333665, Length: 556, Distance: 1362
# [DEBUG] x_pos: 492 | coins: 1 | distance: 452
#
# === EPOCH 48 SUMMARY ===
# avg_reward: [379.9620000000044, 350.33300000000344, 347.02700000000345, 349.4370000000028, 323.9390000000024]
# avg_length: [717.2, 553.6, 577.1, 511.0, 425.0]
# avg_distance: [266, 259, 680, 258, 1362]
# Epoch 48 | Avg Reward: 323.94 | Avg Length: 425.0
# Env 2 done! Reward: 189.55000000000055, Length: 258, Distance: 682
# [DEBUG] x_pos: 606 | coins: 1 | distance: 566
# Env 1 done! Reward: 380.8000000000016, Length: 418, Distance: 681
# [DEBUG] x_pos: 674 | coins: 1 | distance: 634
# Env 3 done! Reward: 318.32666666666717, Length: 245, Distance: 637
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
# Env 4 done! Reward: 176.51000000000286, Length: 490, Distance: 676
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
# Env 6 done! Reward: 395.3500000000027, Length: 451, Distance: 552
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
#
# === EPOCH 49 SUMMARY ===
# avg_reward: [350.33300000000344, 347.02700000000345, 349.4370000000028, 323.9390000000024, 310.2516666666687]
# avg_length: [553.6, 577.1, 511.0, 425.0, 408.9]
# avg_distance: [682, 681, 637, 676, 552]
# Epoch 49 | Avg Reward: 310.25 | Avg Length: 408.9
# Env 0 done! Reward: 227.01000000000312, Length: 539, Distance: 858
# [DEBUG] x_pos: 898 | coins: 1 | distance: 858
# Env 6 done! Reward: 348.83000000000135, Length: 277, Distance: 554
# [DEBUG] x_pos: 78 | coins: 0 | distance: 38
#
# === EPOCH 50 SUMMARY ===
# avg_reward: [347.02700000000345, 349.4370000000028, 323.9390000000024, 310.2516666666687, 313.5926666666688]
# avg_length: [577.1, 511.0, 425.0, 408.9, 415.7]
# avg_distance: [637, 676, 552, 858, 554]
# Epoch 50 | Avg Reward: 313.59 | Avg Length: 415.7
# Env 6 done! Reward: 151.88000000000088, Length: 199, Distance: 554
# [DEBUG] x_pos: 720 | coins: 0 | distance: 680
# Env 5 done! Reward: 353.5300000000047, Length: 708, Distance: 258
# [DEBUG] x_pos: 722 | coins: 0 | distance: 682
# Env 3 done! Reward: 556.1600000000038, Length: 622, Distance: 668
# [DEBUG] x_pos: 722 | coins: 0 | distance: 682
#
# === EPOCH 51 SUMMARY ===
# avg_reward: [349.4370000000028, 323.9390000000024, 310.2516666666687, 313.5926666666688, 309.79466666666883]
# avg_length: [511.0, 425.0, 408.9, 415.7, 420.7]
# avg_distance: [858, 554, 554, 258, 668]
# Epoch 51 | Avg Reward: 309.79 | Avg Length: 420.7
# Env 2 done! Reward: 431.88000000000574, Length: 784, Distance: 1083
# [DEBUG] x_pos: 722 | coins: 0 | distance: 682
# Env 1 done! Reward: 813.6400000000065, Length: 930, Distance: 2426
# [DEBUG] x_pos: 855 | coins: 0 | distance: 815
#
# === EPOCH 52 SUMMARY ===
# avg_reward: [323.9390000000024, 310.2516666666687, 313.5926666666688, 309.79466666666883, 377.31166666666985]
# avg_length: [425.0, 408.9, 415.7, 420.7, 524.5]
# avg_distance: [554, 258, 668, 1083, 2426]
# Epoch 52 | Avg Reward: 377.31 | Avg Length: 524.5
# Env 4 done! Reward: 414.7700000000063, Length: 897, Distance: 858
# [DEBUG] x_pos: 217 | coins: 0 | distance: 177
# Env 5 done! Reward: 359.850000000002, Length: 410, Distance: 250
# [DEBUG] x_pos: 246 | coins: 1 | distance: 206
# Env 0 done! Reward: 356.6866666666705, Length: 672, Distance: 241
# [DEBUG] x_pos: 281 | coins: 1 | distance: 241
# Env 6 done! Reward: 420.7633333333354, Length: 446, Distance: 621
# [DEBUG] x_pos: 66 | coins: 0 | distance: 26
# Env 2 done! Reward: 387.1200000000032, Length: 463, Distance: 538
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
# Env 3 done! Reward: 485.01000000000266, Length: 531, Distance: 829
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
# Env 4 done! Reward: 174.82000000000102, Length: 229, Distance: 613
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
# Env 1 done! Reward: 428.3700000000016, Length: 316, Distance: 662
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
#
# === EPOCH 53 SUMMARY ===
# avg_reward: [310.2516666666687, 313.5926666666688, 309.79466666666883, 377.31166666666985, 427.29100000000346]
# avg_length: [408.9, 415.7, 420.7, 524.5, 567.8]
# avg_distance: [621, 538, 829, 613, 662]
# Epoch 53 | Avg Reward: 427.29 | Avg Length: 567.8
# Env 0 done! Reward: 259.3100000000002, Length: 186, Distance: 682
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
# Env 7 done! Reward: 333.59000000001004, Length: 1435, Distance: 678
# [DEBUG] x_pos: 594 | coins: 0 | distance: 554
# Env 4 done! Reward: 152.4000000000007, Length: 159, Distance: 549
# [DEBUG] x_pos: 594 | coins: 0 | distance: 554
#
# === EPOCH 54 SUMMARY ===
# avg_reward: [313.5926666666688, 309.79466666666883, 377.31166666666985, 427.29100000000346, 335.79200000000276]
# avg_length: [415.7, 420.7, 524.5, 567.8, 484.7]
# avg_distance: [613, 662, 682, 678, 549]
# Epoch 54 | Avg Reward: 335.79 | Avg Length: 484.7
# Env 7 done! Reward: 182.1000000000007, Length: 225, Distance: 657
# [DEBUG] x_pos: 722 | coins: 0 | distance: 682
# Env 3 done! Reward: 429.9100000000019, Length: 370, Distance: 661
# [DEBUG] x_pos: 721 | coins: 0 | distance: 681
# Env 5 done! Reward: 532.2966666666704, Length: 562, Distance: 808
# [DEBUG] x_pos: 722 | coins: 0 | distance: 682
# Env 0 done! Reward: 364.530000000002, Length: 385, Distance: 680
# [DEBUG] x_pos: 720 | coins: 0 | distance: 680
#
# === EPOCH 55 SUMMARY ===
# avg_reward: [309.79466666666883, 377.31166666666985, 427.29100000000346, 335.79200000000276, 334.2336666666691]
# avg_length: [420.7, 524.5, 567.8, 484.7, 439.8]
# avg_distance: [549, 657, 661, 808, 680]
# Epoch 55 | Avg Reward: 334.23 | Avg Length: 439.8
# Env 3 done! Reward: 431.2566666666677, Length: 346, Distance: 667
# [DEBUG] x_pos: 897 | coins: 1 | distance: 857
# Env 6 done! Reward: 345.27000000000646, Length: 911, Distance: 682
# [DEBUG] x_pos: 893 | coins: 1 | distance: 853
#
# === EPOCH 56 SUMMARY ===
# avg_reward: [377.31166666666985, 427.29100000000346, 335.79200000000276, 334.2336666666691, 345.9033333333361]
# avg_length: [524.5, 567.8, 484.7, 439.8, 489.5]
# avg_distance: [661, 808, 680, 667, 682]
# Epoch 56 | Avg Reward: 345.90 | Avg Length: 489.5
# Env 5 done! Reward: 362.7300000000022, Length: 433, Distance: 853
# [DEBUG] x_pos: 898 | coins: 1 | distance: 858
# Env
# Env 6 done! Reward: 203.05999999999986, Length: 125, Distance: 265
# [DEBUG] x_pos: 888 | coins: 1 | distance: 848
#
# === EPOCH 65 SUMMARY ===
# avg_reward: [294.74666666666866, 294.74666666666866, 348.66200000000345, 384.4263333333374, 353.89166666666904]
# avg_length: [404.6, 404.6, 585.0, 649.0, 455.1]
# avg_distance: [645, 683, 258, 682, 265]
# Epoch 65 | Avg Reward: 353.89 | Avg Length: 455.1
# Env 7 done! Reward: 556.160000000005, Length: 858, Distance: 681
# [DEBUG] x_pos: 1318 | coins: 1 | distance: 1278
# Env 0 done! Reward: 385.04333333334574, Length: 1633, Distance: 1378
# [DEBUG] x_pos: 1418 | coins: 1 | distance: 1378
#
# === EPOCH 66 SUMMARY ===
# avg_reward: [294.74666666666866, 348.66200000000345, 384.4263333333374, 353.89166666666904, 373.82333333333713]
# avg_length: [404.6, 585.0, 649.0, 455.1, 645.3]
# avg_distance: [258, 682, 265, 681, 1378]
# Epoch 66 | Avg Reward: 373.82 | Avg Length: 645.3
# Env 2 done! Reward: 369.03000000000134, Length: 329, Distance: 857
# [DEBUG] x_pos: 438 | coins: 0 | distance: 398
# Env 6 done! Reward: 429.3200000000029, Length: 493, Distance: 854
# [DEBUG] x_pos: 898 | coins: 0 | distance: 858
#
# === EPOCH 67 SUMMARY ===
# avg_reward: [348.66200000000345, 384.4263333333374, 353.89166666666904, 373.82333333333713, 390.9143333333364]
# avg_length: [585.0, 649.0, 455.1, 645.3, 564.9]
# avg_distance: [265, 681, 1378, 857, 854]
# Epoch 67 | Avg Reward: 390.91 | Avg Length: 564.9
# Env 3 done! Reward: 605.5000000000041, Length: 644, Distance: 655
# [DEBUG] x_pos: 898 | coins: 0 | distance: 858
# Env 0 done! Reward: 239.00000000000142, Length: 347, Distance: 858
# [DEBUG] x_pos: 898 | coins: 0 | distance: 858
# Env 7 done! Reward: 428.0900000000018, Length: 416, Distance: 629
# [DEBUG] x_pos: 275 | coins: 1 | distance: 235
# Env 0 done! Reward: 188.92, Length: 168, Distance: 257
# [DEBUG] x_pos: 297 | coins: 1 | distance: 257
# Env 2 done! Reward: 435.7000000000022, Length: 457, Distance: 640
# [DEBUG] x_pos: 166 | coins: 0 | distance: 126
#
# === EPOCH 68 SUMMARY ===
# avg_reward: [384.4263333333374, 353.89166666666904, 373.82333333333713, 390.9143333333364, 383.98233333333644]
# avg_length: [649.0, 455.1, 645.3, 564.9, 547.0]
# avg_distance: [655, 858, 629, 257, 640]
# Epoch 68 | Avg Reward: 383.98 | Avg Length: 547.0
# Env 6 done! Reward: 183.03000000000193, Length: 358, Distance: 682
# [DEBUG] x_pos: 722 | coins: 0 | distance: 682
# ...
# Epoch 481 | Avg Reward: 369.97 | Avg Length: 517.6
# Env 5 done! Reward: 309.0400000000004, Length: 221, Distance: 264
# [DEBUG] x_pos: 239 | coins: 1 | distance: 199
# Env 7 done! Reward: 354.4400000000037, Length: 635, Distance: 681
# [DEBUG] x_pos: 339 | coins: 1 | distance: 299
# Env 6 done! Reward: 543.180000000007, Length: 1208, Distance: 682
# [DEBUG] x_pos: 591 | coins: 1 | distance: 551
# Env 5 done! Reward: 268.1600000000003, Length: 184, Distance: 678
# [DEBUG] x_pos: 711 | coins: 1 | distance: 671
# Env 4 done! Reward: 450.9800000000077, Length: 985, Distance: 642
# [DEBUG] x_pos: 721 | coins: 1 | distance: 681
#
# === EPOCH 482 SUMMARY ===
# avg_reward: [302.1036666666686, 263.18766666666846, 260.70366666666905, 369.96533333333605, 424.61666666667077]
# avg_length: [395.1, 386.0, 451.0, 517.6, 687.6]
# avg_distance: [264, 681, 682, 678, 642]
# Epoch 482 | Avg Reward: 424.62 | Avg Length: 687.6
# Env 0 done! Reward: 252.61000000000195, Length: 373, Distance: 681
# [DEBUG] x_pos: 721 | coins: 1 | distance: 681
# Env 2 done! Reward: 242.72000000000298, Length: 568, Distance: 682
# [DEBUG] x_pos: 71 | coins: 0 | distance: 31
# Env 1 done! Reward: 227.0300000000031, Length: 590, Distance: 857
# [DEBUG] x_pos: 410 | coins: 1 | distance: 370
# Env 7 done! Reward: 180.24000000000234, Length: 411, Distance: 680
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
#
# === EPOCH 483 SUMMARY ===
# avg_reward: [263.18766666666846, 260.70366666666905, 369.96533333333605, 424.61666666667077, 338.29800000000336]
# avg_length: [386.0, 451.0, 517.6, 687.6, 594.5]
# avg_distance: [642, 681, 682, 857, 680]
# Epoch 483 | Avg Reward: 338.30 | Avg Length: 594.5
# Env 2 done! Reward: 311.26666666666745, Length: 240, Distance: 236
# [DEBUG] x_pos: 713 | coins: 1 | distance: 673
# Env 1 done! Reward: 425.5300000000008, Length: 332, Distance: 269
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
# Env 4 done! Reward: 440.18000000000285, Length: 524, Distance: 1096
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
#
# === EPOCH 484 SUMMARY ===
# avg_reward: [260.70366666666905, 369.96533333333605, 424.61666666667077, 338.29800000000336, 334.18966666666967]
# avg_length: [451.0, 517.6, 687.6, 594.5, 541.5]
# avg_distance: [857, 680, 236, 269, 1096]
# Epoch 484 | Avg Reward: 334.19 | Avg Length: 541.5
# Env 6 done! Reward: 355.71000000000436, Length: 715, Distance: 664
# [DEBUG] x_pos: 719 | coins: 1 | distance: 679
# Env 3 done! Reward: 786.0200000000061, Length: 1010, Distance: 1076
# [DEBUG] x_pos: 716 | coins: 1 | distance: 676
# Env 0 done! Reward: 177.3600000000036, Length: 585, Distance: 678
# [DEBUG] x_pos: 718 | coins: 1 | distance: 678
# Env 5 done! Reward: 516.0200000000057, Length: 836, Distance: 851
# [DEBUG] x_pos: 594 | coins: 0 | distance: 554
#
# === EPOCH 485 SUMMARY ===
# avg_reward: [369.96533333333605, 424.61666666667077, 338.29800000000336, 334.18966666666967, 366.20766666667]
# avg_length: [517.6, 687.6, 594.5, 541.5, 581.1]
# avg_distance: [1096, 664, 1076, 678, 851]
# Epoch 485 | Avg Reward: 366.21 | Avg Length: 581.1
# Env 2 done! Reward: 169.4600000000048, Length: 733, Distance: 682
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
#
# === EPOCH
# avg_length: [597.6, 727.5, 665.8, 529.4, 476.8]
# avg_distance: [232, 223, 646, 669, 269]
# Epoch 490 | Avg Reward: 340.56 | Avg Length: 476.8
# Env 6 done! Reward: 418.2400000000016, Length: 322, Distance: 199
# [DEBUG] x_pos: 461 | coins: 1 | distance: 421
# Env 7 done! Reward: 190.5200000000005, Length: 178, Distance: 682
# [DEBUG] x_pos: 507 | coins: 1 | distance: 467
# Env 5 done! Reward: 178.09000000000273, Length: 493, Distance: 681
# [DEBUG] x_pos: 591 | coins: 1 | distance: 551
# Env 0 done! Reward: 644.6000000000081, Length: 1198, Distance: 682
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
#
# === EPOCH 491 SUMMARY ===
# avg_reward: [444.06700000000427, 379.70766666667066, 326.8950000000031, 340.55933333333604, 352.9893333333356]
# avg_length: [727.5, 665.8, 529.4, 476.8, 446.6]
# avg_distance: [269, 199, 682, 681, 682]
# Epoch 491 | Avg Reward: 352.99 | Avg Length: 446.6
# Env 7 done! Reward: 198.08999999999983, Length: 136, Distance: 258
# [DEBUG] x_pos: 37 | coins: 0 | distance: -3
# Env 2 done! Reward: 411.35000000000304, Length: 553, Distance: 677
# [DEBUG] x_pos: 73 | coins: 0 | distance: 33
# Env 3 done! Reward: 463.51000000000363, Length: 595, Distance: 823
# [DEBUG] x_pos: 248 | coins: 0 | distance: 208
# Env 4 done! Reward: 572.8000000000042, Length: 627, Distance: 524
# [DEBUG] x_pos: 271 | coins: 0 | distance: 231
# Env 0 done! Reward: 190.3266666666666, Length: 162, Distance: 244
# [DEBUG] x_pos: 284 | coins: 0 | distance: 244
# Env 3 done! Reward: 146.25000000000045, Length: 126, Distance: 518
# [DEBUG] x_pos: 594 | coins: 1 | distance: 554
#
# === EPOCH 492 SUMMARY ===
# avg_reward: [379.70766666667066, 326.8950000000031, 340.55933333333604, 352.9893333333356, 341.3776666666691]
# avg_length: [665.8, 529.4, 476.8, 446.6, 439.0]
# avg_distance: [677, 823, 524, 244, 518]
# Epoch 492 | Avg Reward: 341.38 | Avg Length: 439.0
# Env 1 done! Reward: 783.6000000000076, Length: 1370, Distance: 682
# [DEBUG] x_pos: 208 | coins: 1 | distance: 168
# Env 5 done! Reward: 175.31000000000213, Length: 412, Distance: 666
# [DEBUG] x_pos: 311 | coins: 1 | distance: 271
# Env 7 done! Reward: 313.71000000000123, Length: 338, Distance: 681
# [DEBUG] x_pos: 675 | coins: 1 | distance: 635
# Env 3 done! Reward: 312.81333333333384, Length: 208, Distance: 248
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
# Env 4 done! Reward: 310.50000000000085, Length: 286, Distance: 269
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
# Env 0 done! Reward: 386.0000000000014, Length: 291, Distance: 682
# [DEBUG] x_pos: 722 | coins: 1 | distance: 682
#
# === EPOCH 493 SUMMARY ===
# avg_reward: [326.8950000000031, 340.55933333333604, 352.9893333333356, 341.3776666666691, 365.4820000000022]
# avg_length: [529.4, 476.8, 446.6, 439.0, 441.5]
# avg_distance: [666, 681, 248, 269, 682]
# Epoch 493 | Avg Reward: 365.48 | Avg Length: 441.5
# Env 3 done! Reward: 305.68000000000035, Length: 243, Distance: 260
# Env 7 done! Reward: 299.9100000000041, Length: 622, Distance: 858
# [DEBUG] x_pos: 458 | coins: 0 | distance: 418
#
# === EPOCH 497 SUMMARY ===
# avg_reward: [365.4820000000022, 328.09000000000157, 318.2613333333353, 289.8803333333366, 307.84400000000335]
# avg_length: [441.5, 373.7, 387.7, 553.4, 549.6]
# avg_distance: [254, 682, 1383, 676, 858]
# Epoch 497 | Avg Reward: 307.84 | Avg Length: 549.6
# Env 2 done! Reward: 185.50000000000233, Length: 426, Distance: 681
# [DEBUG] x_pos: 898 | coins: 0 | distance: 858
# Env 4 done! Reward: 441.0400000000026, Length: 503, Distance: 1097
# [DEBUG] x_pos: 897 | coins: 0 | distance: 857
# Env 3 done! Reward: 309.8300000000011, Length: 292, Distance: 255
# [DEBUG] x_pos: 898 | coins: 0 | distance: 858
# Env 5 done! Reward: 476.8500000000043, Length: 676, Distance: 858
# [DEBUG] x_pos: 890 | coins: 0 | distance: 850
#
# === EPOCH 498 SUMMARY ===
# avg_reward: [328.09000000000157, 318.2613333333353, 289.8803333333366, 307.84400000000335, 330.7180000000026]
# avg_length: [373.7, 387.7, 553.4, 549.6, 455.0]
# avg_distance: [858, 681, 1097, 255, 858]
# Epoch 498 | Avg Reward: 330.72 | Avg Length: 455.0
# Env 4 done! Reward: 322.13000000000113, Length: 264, Distance: 681
# [DEBUG] x_pos: 1329 | coins: 0 | distance: 1289
# Env 1 done! Reward: 246.1500000000032, Length: 521, Distance: 680
# [DEBUG] x_pos: 1410 | coins: 0 | distance: 1370
# Env 0 done! Reward: 412.47000000000344, Length: 591, Distance: 1369
# [DEBUG] x_pos: 1409 | coins: 0 | distance: 1369
#
# === EPOCH 499 SUMMARY ===
# avg_reward: [318.2613333333353, 289.8803333333366, 307.84400000000335, 330.7180000000026, 338.68000000000245]
# avg_length: [387.7, 553.4, 549.6, 455.0, 448.4]
# avg_distance: [255, 858, 681, 680, 1369]
# Epoch 499 | Avg Reward: 338.68 | Avg Length: 448.4
# Env 6 done! Reward: 462.716666666671, Length: 624, Distance: 629
# [DEBUG] x_pos: 594 | coins: 1 | distance: 555
# Env 7 done! Reward: 230.7400000000041, Length: 666, Distance: 682
# [DEBUG] x_pos: 604 | coins: 1 | distance: 565
# Env 4 done! Reward: 425.140000000001, Length: 331, Distance: 631
# [DEBUG] x_pos: 464 | coins: 1 | distance: 425
#
# === EPOCH 500 SUMMARY ===
# avg_reward: [289.8803333333366, 307.84400000000335, 330.7180000000026, 338.68000000000245, 351.2566666666695]
# avg_length: [553.4, 549.6, 455.0, 448.4, 489.4]
# avg_distance: [680, 1369, 629, 682, 631]
# Epoch 500 | Avg Reward: 351.26 | Avg Length: 489.4
# /home/lharms/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 155
#     153 line1 = ax1.plot(x, avg_reward, 'b-', label='Avg Reward')
#     154 line2 = ax2.plot(x, avg_length, 'r-', label='Avg Length')
# --> 155 line3 = ax3.plot(x, avg_distance, 'g-', label='Avg Distance')
#     157 ax1.set_xlabel('Epoch')
#     158 ax1.set_ylabel('Avg Reward', color='b')
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py:498, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     495     self.axes.yaxis.update_units(y)
#     497 if x.shape[0] != y.shape[0]:
# --> 498     raise ValueError(f"x and y must have same first dimension, but "
#     499                      f"have shapes {x.shape} and {y.shape}")
#     500 if x.ndim > 2 or y.ndim > 2:
#     501     raise ValueError(f"x and y can be no greater than 2D, but have "
#     502                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (500,) and (1880,)
